# %% [markdown]
# <a href="https://colab.research.google.com/github/astrathh/ProjetoWeb/blob/master/PrimeiroNotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importação da TensorFlow**

# %%
import tensorflow as tf

# %% [markdown]
# *Exibir a versão*

# %%
tf.__version__
# Out:
# '2.11.0'

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import cv2 as cv

# %%
cv.__version__
# Out:
# '4.6.0'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pwd
# Out:
# '/content'

# %% [markdown]
# **cv.imshow()** leva ao crash do Colab, então foi desabilitado pelos desenvolvedores do Colab.

# %%
from google.colab.patches import cv2_imshow
image = cv.imread('/content/drive/MyDrive/Colab Notebooks/Imagens/powerslave.jpg')
(width, height, channels) = image.shape
cv2_imshow(cv.resize(image, (int(width/2), int(height/2))))
# Out:
# <PIL.Image.Image image mode=RGB size=320x317 at 0x7F19F7AC7AC0>

# %%
# !ls /bin
# Out:
# '['				      mpexpand
#  2to3-2.7			      mpic++
#  7z				      mpicalc
#  7za				      mpicc
#  7zr				      mpiCC
#  aclocal			      mpicc.openmpi
#  aclocal-1.16			      mpiCC.openmpi
#  acyclic			      mpic++.openmpi
#  add-apt-repository		      mpicxx
#  addpart			      mpicxx.openmpi
#  addr2line			      mpiexec
#  apropos			      mpiexec.openmpi
#  apt				      mpif77
#  apt-add-repository		      mpif77.openmpi
#  apt-cache			      mpif90
#  apt-cdrom			      mpif90.openmpi
#  apt-config			      mpifort
#  apt-extracttemplates		      mpifort.openmpi
#  apt-ftparchive			      mpirun
#  apt-get			      mpirun.openmpi
#  apt-key			      mtrace
#  apt-mark			      mutter
#  apt-sortpkgs			      mv
#  ar				      mysql_config
#  arch				      namei
#  as				      nawk
#  asan_symbolize			      ncal
#  asan_symbolize-10		      nc-config
#  assistant			      ncurses5-config
#  autoconf			      ncurses6-config
#  autoheader			      ncursesw5-config
# ...

# %%
! ls "/content/drive/MyDrive/Colab Notebooks"
# Out:
# datasets  GraficoOnline.ipynb  Imagens	mnist.py  PrimeiroNotebook.ipynb

# %%
! python3  "/content/drive/MyDrive/Colab Notebooks/mnist.py"
# Out:
# 2023-02-27 13:05:16.874327: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib/python3.8/dist-packages/cv2/../../lib64:/usr/lib64-nvidia
# 2023-02-27 13:05:16.874431: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib/python3.8/dist-packages/cv2/../../lib64:/usr/lib64-nvidia
# 2023-02-27 13:05:16.874452: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# ...

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13297200 kB
# MemFree:         6489952 kB
# MemAvailable:   12022432 kB
# Buffers:          348756 kB
# Cached:          5339592 kB
# SwapCached:            0 kB
# Active:           951404 kB
# Inactive:        5536252 kB
# Active(anon):       1060 kB
# Inactive(anon):   772732 kB
# Active(file):     950344 kB
# Inactive(file):  4763520 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               288 kB
# Writeback:             0 kB
# AnonPages:        799340 kB
# Mapped:           571044 kB
# Shmem:              1320 kB
# KReclaimable:     120132 kB
# Slab:             158976 kB
# SReclaimable:     120132 kB
# SUnreclaim:        38844 kB
# KernelStack:        5568 kB
# PageTables:        13116 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6648600 kB
# Committed_AS:    3648292 kB
# VmallocTotal:   34359738367 kB
# ...

# %%
! pip install imutils
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
